# %%
# !nvidia-smi
# Out:
# Sat Sep 28 20:38:29 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8              10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.1/875.1 kB 17.7 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
#!yolo task=detect mode=predict model=yolov8l.pt conf=0.25 source='https://ultralytics.com/images/bus.jpg'

# %%
#!yolo task=detect""" we could write segment - detect - classify here""" mode=predict """ we could write train/val here""" model=yolov8l.pt conf=0.25 source='https://ultralytics.com/images/bus.jpg' # write data = if you are training

# %%
# !yolo task=detect mode=train model=yolov8l.pt data=../content/drive/MyDrive/Keras/Object-detect-yolo/data.yaml epochs=50 imgsz=640 batch=16
# Out:
# Ultralytics YOLOv8.2.103 🚀 Python-3.10.12 torch-2.4.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
import  matplotlib.pyplot as plt

# %%
# !yolo detect val model=path/to/best.pt save_json=True  # val custom model

# %%
# !yolo detect predict model=path/to/best.pt source='https://ultralytics.com/images/bus.jpg'

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread("/content/runs/detect/train3/F1_curve.png")
plt.imshow(img)
plt.show()

# %%
img = cv2.imread("/content/runs/detect/train3/PR_curve.png")
plt.imshow(img)
plt.show()

# %%
img = cv2.imread("/content/runs/detect/train3/P_curve.png")
plt.imshow(img)
plt.show()

# %%
img = cv2.imread("/content/runs/detect/train3/R_curve.png")
plt.imshow(img)
plt.show()

# %%
img = cv2.imread("/content/runs/detect/train3/confusion_matrix.png")
plt.imshow(img)
plt.show()

# %%
img = cv2.imread("/content/runs/detect/train3/confusion_matrix_normalized.png")
plt.imshow(img)
plt.show()

# %%
img = cv2.imread("/content/runs/detect/train3/val_batch2_pred.jpg")
plt.imshow(img)
plt.show()

# %%
path = "/content/runs/detect/train3/results.png"
img = cv2.imread(path)
plt.imshow(img)
plt.show()
